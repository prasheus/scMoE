# %%
import scanpy as sc 
import pandas as pd

# %%
adata = sc.read_mtx('Data_Wu2021_Breast/Exp_data_UMIcounts.mtx')

# %%
genes = pd.read_csv('Data_Wu2021_Breast/Genes.txt', header=None, sep='\t').iloc[:,0].tolist()

# %%
adata = adata.T
adata.var_names = genes

# %%
# combining with cell metadata (barcode as index)
cells = pd.read_csv('Data_Wu2021_Breast/Cells.csv', index_col=0)
# Out:
# /tmp/ipykernel_102002/3066248905.py:2: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   cells = pd.read_csv('Data_Wu2021_Breast/Cells.csv', index_col=0)

# %%
assert len(cells) == adata.n_obs

# barcodes should match cells

# %%
adata.obs_names = cells.index

# %%
adata.obs = adata.obs.join(cells, how='left')

# %%
adata.obs['study'] = 'Wu2021'

# %%
adata.obs.head()
# Out:
#                            sample  patient    cell_type       cell_subtype  \
# cell_name
# CID3586_AAGACCTCAGCATGAG  CID3586  CID3586  Endothelial  Endothelial ACKR1
# CID3586_AAGGTTCGTAGTACCT  CID3586  CID3586  Endothelial  Endothelial ACKR1
# CID3586_ACCAGTAGTTGTGGCC  CID3586  CID3586  Endothelial  Endothelial ACKR1
# CID3586_ACCCACTAGATGTCGG  CID3586  CID3586  Endothelial  Endothelial ACKR1
# CID3586_ACTGATGGTCAACTGT  CID3586  CID3586  Endothelial  Endothelial ACKR1
#
#                           complexity  umap1   umap2  g1s_score  g2m_score  \
# cell_name
# CID3586_AAGACCTCAGCATGAG        1689  7.161 -2.3643     0.0414     0.0773
# CID3586_AAGGTTCGTAGTACCT         779    NaN     NaN        NaN        NaN
# CID3586_ACCAGTAGTTGTGGCC         514    NaN     NaN        NaN        NaN
# CID3586_ACCCACTAGATGTCGG         609    NaN     NaN        NaN        NaN
# CID3586_ACTGATGGTCAACTGT         807    NaN     NaN        NaN        NaN
#
#                          cell_cycle_phase  ...         PR HER2_IHC  \
# cell_name                                  ...
# CID3586_AAGACCTCAGCATGAG      Not cycling  ...  100% 2-3+       3+
# CID3586_AAGGTTCGTAGTACCT              NaN  ...  100% 2-3+       3+
# CID3586_ACCAGTAGTTGTGGCC              NaN  ...  100% 2-3+       3+
# CID3586_ACCCACTAGATGTCGG              NaN  ...  100% 2-3+       3+
# CID3586_ACTGATGGTCAACTGT              NaN  ...  100% 2-3+       3+
#
#                            HER2_ISH_ratio    Ki67 subtype_IHC treatment  \
# cell_name
# CID3586_AAGACCTCAGCATGAG  Amplified (6.8)  30-50%   HER2+/ER+     Naïve
# CID3586_AAGGTTCGTAGTACCT  Amplified (6.8)  30-50%   HER2+/ER+     Naïve
# CID3586_ACCAGTAGTTGTGGCC  Amplified (6.8)  30-50%   HER2+/ER+     Naïve
# CID3586_ACCCACTAGATGTCGG  Amplified (6.8)  30-50%   HER2+/ER+     Naïve
# CID3586_ACTGATGGTCAACTGT  Amplified (6.8)  30-50%   HER2+/ER+     Naïve
#
#                           details_treatment  \
# cell_name
# CID3586_AAGACCTCAGCATGAG                  -
# CID3586_AAGGTTCGTAGTACCT                  -
# CID3586_ACCAGTAGTTGTGGCC                  -
# CID3586_ACCCACTAGATGTCGG                  -
# CID3586_ACTGATGGTCAACTGT                  -
#
#                                               notable_pathological_features  \
# cell_name
# CID3586_AAGACCTCAGCATGAG  Multifocal tumour with associatied high grade ...
# CID3586_AAGGTTCGTAGTACCT  Multifocal tumour with associatied high grade ...
# CID3586_ACCAGTAGTTGTGGCC  Multifocal tumour with associatied high grade ...
# CID3586_ACCCACTAGATGTCGG  Multifocal tumour with associatied high grade ...
# CID3586_ACTGATGGTCAACTGT  Multifocal tumour with associatied high grade ...
#
#                                 stage   study
# cell_name
# CID3586_AAGACCTCAGCATGAG  pT(m)2, N2a  Wu2021
# CID3586_AAGGTTCGTAGTACCT  pT(m)2, N2a  Wu2021
# CID3586_ACCAGTAGTTGTGGCC  pT(m)2, N2a  Wu2021
# CID3586_ACCCACTAGATGTCGG  pT(m)2, N2a  Wu2021
# CID3586_ACTGATGGTCAACTGT  pT(m)2, N2a  Wu2021
#
# [5 rows x 30 columns]

# %%
study_files = {
    "Azizi2018_InDrop": {
        "matrix": "Data_Azizi2018_Breast/InDrop/Exp_data_UMIcounts.mtx",
        "genes":  "Data_Azizi2018_Breast/InDrop/Genes.txt",
        "cells":  "Data_Azizi2018_Breast/InDrop/Cells.csv",
        "samples": "Data_Azizi2018_Breast/Samples.csv",
        "units": "UMI"
    },
    "Azizi2018_10x": {
        "matrix": "Data_Azizi2018_Breast/10x/Exp_data_UMIcounts.mtx",
        "genes":  "Data_Azizi2018_Breast/10x/Genes.txt",
        "cells":  "Data_Azizi2018_Breast/10x/Cells.csv",
        "samples": "Data_Azizi2018_Breast/Samples.csv",
        "units": "UMI"
    },
    "Bassez2021": {
        "matrix": "Data_Bassez2021_Breast/Exp_data_UMIcounts.mtx",
        "genes":  "Data_Bassez2021_Breast/Genes.txt",
        "cells":  "Data_Bassez2021_Breast/Cells.csv",
        "samples": "Data_Bassez2021_Breast/Samples.csv",
        "units": "UMI"
    },
    "Chung2017": {
        "matrix": "Data_Chung2017_Breast/Exp_data_TPM.mtx",
        "genes":  "Data_Chung2017_Breast/Genes.txt",
        "cells":  "Data_Chung2017_Breast/Cells.csv",
        "samples": "Data_Chung2017_Breast/Samples.csv",
        "units": "TPM"
    },
    "Gao2021_Breast": {
        "matrix": "Data_Gao2021_Breast/Breast/Exp_data_UMIcounts.mtx",
        "genes":  "Data_Gao2021_Breast/Breast/Genes.txt",
        "cells":  "Data_Gao2021_Breast/Breast/Cells.csv",
        "samples": "Data_Gao2021_Breast/Samples.csv",
        "units": "UMI"
    },
    "Gao2021_Breast_and_thyroid": {
        "matrix": "Data_Gao2021_Breast/Breast_and_thyroid/exp_data_UMIcountscells_breast_and_thyroid.mtx",
        "genes":  "Data_Gao2021_Breast/Breast_and_thyroid/genes_breast_and_thyroid.txt",
        "cells":  "Data_Gao2021_Breast/Breast_and_thyroid/Cells_breast_and_thyroid.csv",
        "samples": "Data_Gao2021_Breast/Samples.csv",
        "units": "UMI"
    },
    "Griffiths2021_iCell8": {
        "matrix": "Data_Griffiths2021_Breast/iCell8/Exp_data_UMIcounts.mtx",
        "genes":  "Data_Griffiths2021_Breast/iCell8/Genes.txt",
        "cells":  "Data_Griffiths2021_Breast/iCell8/Cells.csv",
        "samples": "Data_Griffiths2021_Breast/Samples.csv",
        "units": "UMI"
    },
    "Griffiths2021_10X": {
        "matrix": "Data_Griffiths2021_Breast/10X/Exp_data_UMIcounts.mtx",
        "genes":  "Data_Griffiths2021_Breast/10X/Genes.txt",
        "cells":  "Data_Griffiths2021_Breast/10X/Cells.csv",
        "samples": "Data_Griffiths2021_Breast/Samples.csv",
        "units": "UMI"
    },
    "Gulati2020": {
        "matrix": "Data_Gulati2020_Breast/Exp_data_TPM.mtx",
        "genes":  "Data_Gulati2020_Breast/Genes.txt",
        "cells":  "Data_Gulati2020_Breast/Cells.csv",
        "samples": "Data_Gulati2020_Breast/Samples.csv",
        "units": "TPM"
    },
    "Karaayvas2018": {
        "matrix": "Data_Karaayvas2018_Breast/Exp_data_TPM.mtx",
        "genes":  "Data_Karaayvas2018_Breast/Genes.txt",
        "cells":  "Data_Karaayvas2018_Breast/Cells.csv",
        "samples": "Data_Karaayvas2018_Breast/Samples.csv",
        "units": "TPM"
    },
    "Kim2018": {
        "matrix": "Data_Kim2018_Breast/Exp_data_TPM.mtx",
        "genes":  "Data_Kim2018_Breast/Genes.txt",
        "cells":  "Data_Kim2018_Breast/Cells.csv",
        "samples": "Data_Kim2018_Breast/Samples.csv",
        "units": "TPM"
    },
    # below has same gene as in the parent folder
    "Pal2021_Group1": {
        "matrix": "Data_Pal2021_Breast/Group1/Exp_data_UMIcounts1.mtx",
        "genes":  "Data_Pal2021_Breast/Genes.txt",
        "cells":  "Data_Pal2021_Breast/Group1/Cells1.csv",
        "samples": "Data_Pal2021_Breast/Samples.csv",
        "units": "UMI"
    },
    "Pal2021_Group2": {
        "matrix": "Data_Pal2021_Breast/Group2/Exp_data_UMIcounts2.mtx",
        "genes":  "Data_Pal2021_Breast/Genes.txt",
        "cells":  "Data_Pal2021_Breast/Group2/Cells2.csv",
        "samples": "Data_Pal2021_Breast/Samples.csv",
        "units": "UMI"
    },
    "Pal2021_Group3": {
        "matrix": "Data_Pal2021_Breast/Group3/Exp_data_UMIcounts3.mtx",
        "genes":  "Data_Pal2021_Breast/Genes.txt",
        "cells":  "Data_Pal2021_Breast/Group3/Cells3.csv",
        "samples": "Data_Pal2021_Breast/Samples.csv",
        "units": "UMI"
    },
    "Pal2021_Group4": {
        "matrix": "Data_Pal2021_Breast/Group4/Exp_data_UMIcounts4.mtx",
        "genes":  "Data_Pal2021_Breast/Genes.txt",
        "cells":  "Data_Pal2021_Breast/Group4/Cells4.csv",
        "samples": "Data_Pal2021_Breast/Samples.csv",
        "units": "UMI"
    },
    "Pal2021_Group5": {
        "matrix": "Data_Pal2021_Breast/Group5/Exp_data_UMIcounts5.mtx",
        "genes":  "Data_Pal2021_Breast/Genes.txt",
        "cells":  "Data_Pal2021_Breast/Group5/Cells5.csv",
        "samples": "Data_Pal2021_Breast/Samples.csv",
        "units": "UMI"
    },
    "Qian2020": {
        "matrix": "Data_Qian2020_Breast/Exp_data_UMIcounts.mtx",
        "genes":  "Data_Qian2020_Breast/Genes.txt",
        "cells":  "Data_Qian2020_Breast/Cells.csv",
        "samples": "Data_Qian2020_Breast/Samples.csv",
        "units": "UMI"
    },
    "Savas2018": {
        "matrix": "Data_Savas2018_Breast/Exp_data_UMIcounts.mtx",
        "genes":  "Data_Savas2018_Breast/Genes.txt",
        "cells":  "Data_Savas2018_Breast/Cells.csv",
        "samples": "Data_Savas2018_Breast/Samples.csv",
        "units": "UMI"
    },
    "Wu2021": {
        "matrix": "Data_Wu2021_Breast/Exp_data_UMIcounts.mtx",
        "genes":  "Data_Wu2021_Breast/Genes.txt",
        "cells":  "Data_Wu2021_Breast/Cells.csv",
        "samples": "Data_Wu2021_Breast/Samples.csv",
        "units": "UMI"
    }
}

# %%
import os

# %%
adatas = []
for name, paths in study_files.items():
    matrix_path = paths["matrix"]
    genes_path = paths["genes"]
    cells_path = paths["cells"]
    if not os.path.exists(matrix_path) or not os.path.exists(genes_path) or not os.path.exists(cells_path):
        print(f"{name}: missing file")
        continue

    ad = sc.read_mtx(matrix_path).T  

    gene_df = pd.read_csv(genes_path, header=None, sep="\t")
    ad.var_names = gene_df.iloc[:, 0].tolist()

    cells_df = pd.read_csv(cells_path, index_col=0)
    assert len(cells_df) == ad.n_obs, f"barcode mismatch in {name}: {len(cells_df)} barcodes vs {ad.n_obs} cells"
    ad.obs_names = cells_df.index
    ad.obs = ad.obs.join(cells_df, how="left")

    ad.obs["study"] = name
    ad.obs["batch"] = name
    ad.obs["matrix_units"] = paths["units"]

    adatas.append(ad)
# Out:
# /home/pandeyps/.pyenv/versions/3.11.9/lib/python3.11/site-packages/anndata/_core/anndata.py:879: UserWarning:
# AnnData expects .obs.index to contain strings, but got values like:
#     [246, 260, 346, 188, 33]
#
#     Inferred to be: integer
#
#   names = self._prep_dim_index(names, "obs")
# /home/pandeyps/.pyenv/versions/3.11.9/lib/python3.11/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /tmp/ipykernel_14705/3773979371.py:15: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   cells_df = pd.read_csv(cells_path, index_col=0)

# %%
ad.n_obs
# Out:
# 100064

# %%
ad.n_vars
# Out:
# 29733

# %%
# join failed (checked for duplicates)
for i, ad in enumerate(adatas):
    dup_genes = ad.var_names.duplicated().sum()
    if dup_genes > 0:
        print(f"{ad.obs['study'].iloc[0]}: {dup_genes} duplicate gene name")
# Out:
# Chung2017: 2055 duplicate gene name
# Pal2021_Group1: 24 duplicate gene name
# Pal2021_Group2: 24 duplicate gene name
# Pal2021_Group3: 24 duplicate gene name
# Pal2021_Group4: 24 duplicate gene name
# Pal2021_Group5: 24 duplicate gene name

# %%
# join all studies
adata_all = adatas[0].concatenate(
    adatas[1:],
    batch_key="batch",
    join="inner",           # to keep genes that are in all of the studies
    index_unique="-"
)
# Out:
# /tmp/ipykernel_14705/1630562197.py:2: FutureWarning: The method concatenate is deprecated and will be removed in the future. Use anndata.concat instead of AnnData.concatenate. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_all = adatas[0].concatenate(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 # join all studies
# ----> 2 adata_all = adatas[0].concatenate(
#       3     adatas[1:],
#       4     batch_key="batch",
#       5     join="inner",           # to keep genes that are in all of the studies
#       6     index_unique="-"
#       7 )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/typing_extensions.py:3004, in deprecated.__call__.<locals>.wrapper(*args, **kwargs)
#    3001 @functools.wraps(arg)
#    3002 def wrapper(*args, **kwargs):
#    3003     warnings.warn(msg, category=category, stacklevel=stacklevel + 1)
# -> 3004     return arg(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/anndata/_core/anndata.py:1817, in AnnData.concatenate(self, join, batch_key, batch_categories, uns_merge, index_unique, fill_value, *adatas)
#    1814     adatas = adatas[0]  # backwards compatibility
#    1815 all_adatas = (self, *adatas)
# -> 1817 out = concat(
#    1818     all_adatas,
#    1819     axis=0,
#    1820     join=join,
#    1821     label=batch_key,
#    1822     keys=batch_categories,
#    1823     uns_merge=uns_merge,
#    1824     fill_value=fill_value,
#    1825     index_unique=index_unique,
#    1826     pairwise=False,
#    1827 )
#    1829 # Backwards compat (some of this could be more efficient)
#    1830 # obs used to always be an outer join
#    1831 sparse_class = sparse.csr_matrix
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/anndata/_core/merge.py:1700, in concat(adatas, axis, join, merge, uns_merge, label, keys, index_unique, fill_value, pairwise, force_lazy)
#    1696 if are_any_alt_annotations_dataframes:
#    1697     alt_annotations_in_memory = [
#    1698         to_memory(a) if isinstance(a, Dataset2D) else a for a in alt_annotations
#    1699     ]
# -> 1700     alt_annot = merge_dataframes(alt_annotations_in_memory, alt_indices, merge)
#    1701 else:
#    1702     # TODO: figure out mapping of our merge to theirs instead of just taking first, although this appears to be
#    1703     # the only "lazy" setting so I'm not sure we really want that.
#    1704     # Because of xarray's merge upcasting, it's safest to simply assume that all dtypes are objects.
#    1705     annotations_with_only_dask = list(
#    1706         make_xarray_extension_dtypes_dask(
#    1707             alt_annotations, use_only_object_dtype=True
#    1708         )
#    1709     )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/anndata/_core/merge.py:1127, in merge_dataframes(dfs, new_index, merge_strategy)
#    1124 def merge_dataframes(
#    1125     dfs: Iterable[pd.DataFrame], new_index, merge_strategy=merge_unique
#    1126 ) -> pd.DataFrame:
# -> 1127     dfs = [df.reindex(index=new_index) for df in dfs]
#    1128     # New dataframe with all shared data
#    1129     new_df = pd.DataFrame(merge_strategy(dfs), index=new_index)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/anndata/_core/merge.py:1127, in <listcomp>(.0)
#    1124 def merge_dataframes(
#    1125     dfs: Iterable[pd.DataFrame], new_index, merge_strategy=merge_unique
#    1126 ) -> pd.DataFrame:
# -> 1127     dfs = [df.reindex(index=new_index) for df in dfs]
#    1128     # New dataframe with all shared data
#    1129     new_df = pd.DataFrame(merge_strategy(dfs), index=new_index)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/pandas/core/frame.py:5400, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5381 @doc(
#    5382     NDFrame.reindex,
#    5383     klass=_shared_doc_kwargs["klass"],
#    (...)   5398     tolerance=None,
#    5399 ) -> DataFrame:
# -> 5400     return super().reindex(
#    5401         labels=labels,
#    5402         index=index,
#    5403         columns=columns,
#    5404         axis=axis,
#    5405         method=method,
#    5406         copy=copy,
#    5407         level=level,
#    5408         fill_value=fill_value,
#    5409         limit=limit,
#    5410         tolerance=tolerance,
#    5411     )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/pandas/core/generic.py:5632, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5629     return self._reindex_multi(axes, copy, fill_value)
#    5631 # perform the reindex on the axes
# -> 5632 return self._reindex_axes(
#    5633     axes, level, limit, tolerance, method, fill_value, copy
#    5634 ).__finalize__(self, method="reindex")
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/pandas/core/generic.py:5655, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5652     continue
#    5654 ax = self._get_axis(a)
# -> 5655 new_index, indexer = ax.reindex(
#    5656     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5657 )
#    5659 axis = self._get_axis_number(a)
#    5660 obj = obj._reindex_with_indexers(
#    5661     {axis: [new_index, indexer]},
#    5662     fill_value=fill_value,
#    5663     copy=copy,
#    5664     allow_dups=False,
#    5665 )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/pandas/core/indexes/base.py:4436, in Index.reindex(self, target, method, level, limit, tolerance)
#    4433     raise ValueError("cannot handle a non-unique multi-index!")
#    4434 elif not self.is_unique:
#    4435     # GH#42568
# -> 4436     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4437 else:
#    4438     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels
